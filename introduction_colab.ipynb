# %%
import numpy as np
import os.path as osp
import torch
import torch.nn.functional as F
from torch_geometric.nn import SplineConv
from torch_geometric.data import Data
from random import shuffle, randint
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
labels = []
N = 1000 
nodes = range(0, N)
node_features = []
edge_features = []

for node in nodes:
  
  #spammer 
  if random.random() > 0.5:
    #more likely to have many connections with a maximum of 1/5 of the nodes in the graph 
    nb_nbrs = int(random.random() * (N/5))
    #more likely to have sent many bytes
    node_features.append((random.random()+1) / 2.)
    #more likely to have a high trust value 
    edge_features += [(random.random()+2)/3.] * nb_nbrs
    #associate a label 
    labels.append(1)
    
  #non-spammer 
  else:
    #at most connected to 10 nbrs 
    nb_nbrs = int(random.random() * 10 + 1)
    #associate more bytes and random bytes 
    node_features.append(random.random())
    edge_features += [random.random()] * nb_nbrs
    labels.append(0)
  
  #connect to some random nodes 
  nbrs = np.random.choice(nodes, size = nb_nbrs)
  nbrs = nbrs.reshape((1, nb_nbrs))
  
  #add the edges of nbrs 
  node_edges = np.concatenate([np.ones((1, nb_nbrs), dtype = np.int32) * node, nbrs], axis = 0)
  
  #add the overall edges 
  if node == 0:
    edges = node_edges
  else:
    edges = np.concatenate([edges, node_edges], axis = 1)

# %%
x = torch.tensor(np.expand_dims(node_features, 1), dtype=torch.float)
y = torch.tensor(labels, dtype=torch.long)

edge_index = torch.tensor(edges, dtype=torch.long)
edge_attr = torch.tensor(np.expand_dims(edge_features, 1), dtype=torch.float)

data = Data(x = x, edge_index=edge_index, y =y, edge_attr=edge_attr )
print(data)
# Out:
# Data(edge_attr=[52577, 1], edge_index=[2, 52577], x=[1000, 1], y=[1000])

# %%
data.train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
data.train_mask[:int(0.8 * data.num_nodes)] = 1 #train only on the 80% nodes
data.test_mask = torch.zeros(data.num_nodes, dtype=torch.bool) #test on 20 % nodes 
data.test_mask[- int(0.2 * data.num_nodes):] = 1

# %% [markdown]
# ## SplineConv

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = SplineConv(1, 16, dim=1, kernel_size=5)
        self.conv2 = SplineConv(16, 32, dim=1, kernel_size=5)
        self.conv3 = SplineConv(32, 64, dim=1, kernel_size=7)
        self.conv4 = SplineConv(64, 128, dim=1, kernel_size=7)
        self.conv5 = SplineConv(128, 128, dim=1, kernel_size=11)
        self.conv6 = SplineConv(128, 2, dim=1, kernel_size=11)

    def forward(self):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        x = F.elu(self.conv1(x, edge_index, edge_attr))
        x = self.conv2(x, edge_index, edge_attr)
        x = F.elu(self.conv3(x, edge_index, edge_attr))
        x = self.conv4(x, edge_index, edge_attr)
        x = F.elu(self.conv5(x, edge_index, edge_attr))
        x = self.conv6(x, edge_index, edge_attr)
        x = F.dropout(x, training = self.training)
        return F.log_softmax(x, dim=1)

# %%
def evaluate_loss(mode = 'train'):
  
  #use masking for loss evaluation 
  if mode == 'train':
    loss = F.nll_loss(model()[data.train_mask], data.y[data.train_mask])
  else:
    loss = F.nll_loss(model()[data.test_mask], data.y[data.test_mask])
  return loss

def train():
  #training 
  model.train()
  optimizer.zero_grad()
  loss = evaluate_loss()
  loss.backward()
  optimizer.step()
  return loss.detach().cpu().numpy() 

def test():
  #testing 
  model.eval()
  logits, accs = model(), []
  loss = evaluate_loss(mode = 'test').detach().cpu().numpy() 

  for _, mask in data('train_mask', 'test_mask'):
      pred = logits[mask].max(1)[1]
      acc = pred.eq(data.y[mask]).sum().item() / mask.sum().item()
      accs.append(acc)
  return [loss] + accs

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model, data = Net().to(device), data.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
losses = []
for epoch in range(1, 200):
  train_loss = train()
  log = 'Epoch: {:03d}, train_loss: {:.3f}, test_loss:{:.3f}, train_acc: {:.2f}, test_acc: {:.2f}'
  test_loss = test()[0]
  losses.append([train_loss,test_loss])
  print(log.format(epoch, train_loss, *test()))
# Out:
# Epoch: 001, train_loss: 0.693, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 002, train_loss: 0.693, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 003, train_loss: 0.692, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 004, train_loss: 0.693, test_loss:0.694, train_acc: 0.52, test_acc: 0.49
# Epoch: 005, train_loss: 0.692, test_loss:0.694, train_acc: 0.52, test_acc: 0.49
# Epoch: 006, train_loss: 0.693, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 007, train_loss: 0.691, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 008, train_loss: 0.690, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 009, train_loss: 0.692, test_loss:0.693, train_acc: 0.52, test_acc: 0.49
# Epoch: 010, train_loss: 0.690, test_loss:0.692, train_acc: 0.52, test_acc: 0.49
# Epoch: 011, train_loss: 0.690, test_loss:0.690, train_acc: 0.52, test_acc: 0.49
# Epoch: 012, train_loss: 0.688, test_loss:0.688, train_acc: 0.52, test_acc: 0.49
# Epoch: 013, train_loss: 0.687, test_loss:0.685, train_acc: 0.57, test_acc: 0.54
# Epoch: 014, train_loss: 0.684, test_loss:0.682, train_acc: 0.68, test_acc: 0.67
# Epoch: 015, train_loss: 0.681, test_loss:0.678, train_acc: 0.73, test_acc: 0.71
# Epoch: 016, train_loss: 0.677, test_loss:0.673, train_acc: 0.75, test_acc: 0.72
# Epoch: 017, train_loss: 0.673, test_loss:0.666, train_acc: 0.76, test_acc: 0.72
# Epoch: 018, train_loss: 0.667, test_loss:0.659, train_acc: 0.73, test_acc: 0.71
# Epoch: 019, train_loss: 0.658, test_loss:0.650, train_acc: 0.74, test_acc: 0.72
# Epoch: 020, train_loss: 0.649, test_loss:0.640, train_acc: 0.74, test_acc: 0.72
# Epoch: 021, train_loss: 0.642, test_loss:0.628, train_acc: 0.74, test_acc: 0.72
# Epoch: 022, train_loss: 0.633, test_loss:0.616, train_acc: 0.74, test_acc: 0.71
# Epoch: 023, train_loss: 0.624, test_loss:0.602, train_acc: 0.73, test_acc: 0.71
# Epoch: 024, train_loss: 0.609, test_loss:0.588, train_acc: 0.72, test_acc: 0.70
# Epoch: 025, train_loss: 0.608, test_loss:0.576, train_acc: 0.71, test_acc: 0.72
# Epoch: 026, train_loss: 0.605, test_loss:0.568, train_acc: 0.70, test_acc: 0.70
# Epoch: 027, train_loss: 0.616, test_loss:0.569, train_acc: 0.71, test_acc: 0.70
# Epoch: 028, train_loss: 0.602, test_loss:0.570, train_acc: 0.71, test_acc: 0.71
# Epoch: 029, train_loss: 0.628, test_loss:0.568, train_acc: 0.70, test_acc: 0.70
# Epoch: 030, train_loss: 0.616, test_loss:0.565, train_acc: 0.69, test_acc: 0.69
# Epoch: 031, train_loss: 0.598, test_loss:0.565, train_acc: 0.68, test_acc: 0.69
# Epoch: 032, train_loss: 0.601, test_loss:0.566, train_acc: 0.69, test_acc: 0.69
# Epoch: 033, train_loss: 0.624, test_loss:0.567, train_acc: 0.70, test_acc: 0.69
# Epoch: 034, train_loss: 0.614, test_loss:0.570, train_acc: 0.71, test_acc: 0.70
# Epoch: 035, train_loss: 0.618, test_loss:0.571, train_acc: 0.71, test_acc: 0.69
# Epoch: 036, train_loss: 0.609, test_loss:0.575, train_acc: 0.71, test_acc: 0.70
# Epoch: 037, train_loss: 0.601, test_loss:0.579, train_acc: 0.71, test_acc: 0.69
# Epoch: 038, train_loss: 0.588, test_loss:0.582, train_acc: 0.71, test_acc: 0.70
# Epoch: 039, train_loss: 0.603, test_loss:0.585, train_acc: 0.71, test_acc: 0.70
# Epoch: 040, train_loss: 0.609, test_loss:0.587, train_acc: 0.71, test_acc: 0.69
# Epoch: 041, train_loss: 0.614, test_loss:0.589, train_acc: 0.70, test_acc: 0.68
# Epoch: 042, train_loss: 0.604, test_loss:0.589, train_acc: 0.70, test_acc: 0.68
# Epoch: 043, train_loss: 0.612, test_loss:0.590, train_acc: 0.71, test_acc: 0.70
# Epoch: 044, train_loss: 0.605, test_loss:0.590, train_acc: 0.72, test_acc: 0.70
# Epoch: 045, train_loss: 0.603, test_loss:0.589, train_acc: 0.72, test_acc: 0.70
# Epoch: 046, train_loss: 0.606, test_loss:0.588, train_acc: 0.72, test_acc: 0.70
# Epoch: 047, train_loss: 0.598, test_loss:0.585, train_acc: 0.72, test_acc: 0.70
# Epoch: 048, train_loss: 0.597, test_loss:0.582, train_acc: 0.72, test_acc: 0.70
# Epoch: 049, train_loss: 0.580, test_loss:0.580, train_acc: 0.71, test_acc: 0.70
# Epoch: 050, train_loss: 0.608, test_loss:0.577, train_acc: 0.71, test_acc: 0.70
# Epoch: 051, train_loss: 0.594, test_loss:0.575, train_acc: 0.71, test_acc: 0.70
# Epoch: 052, train_loss: 0.593, test_loss:0.573, train_acc: 0.70, test_acc: 0.69
# Epoch: 053, train_loss: 0.603, test_loss:0.573, train_acc: 0.71, test_acc: 0.69
# Epoch: 054, train_loss: 0.596, test_loss:0.574, train_acc: 0.72, test_acc: 0.70
# Epoch: 055, train_loss: 0.588, test_loss:0.575, train_acc: 0.72, test_acc: 0.70
# Epoch: 056, train_loss: 0.586, test_loss:0.573, train_acc: 0.71, test_acc: 0.70
# Epoch: 057, train_loss: 0.602, test_loss:0.570, train_acc: 0.70, test_acc: 0.68
# Epoch: 058, train_loss: 0.594, test_loss:0.569, train_acc: 0.69, test_acc: 0.67
# Epoch: 059, train_loss: 0.586, test_loss:0.569, train_acc: 0.69, test_acc: 0.68
# Epoch: 060, train_loss: 0.598, test_loss:0.570, train_acc: 0.70, test_acc: 0.67
# Epoch: 061, train_loss: 0.583, test_loss:0.572, train_acc: 0.70, test_acc: 0.69
# Epoch: 062, train_loss: 0.598, test_loss:0.575, train_acc: 0.71, test_acc: 0.69
# Epoch: 063, train_loss: 0.587, test_loss:0.577, train_acc: 0.72, test_acc: 0.70
# Epoch: 064, train_loss: 0.594, test_loss:0.576, train_acc: 0.72, test_acc: 0.70
# Epoch: 065, train_loss: 0.602, test_loss:0.575, train_acc: 0.71, test_acc: 0.69
# Epoch: 066, train_loss: 0.604, test_loss:0.574, train_acc: 0.70, test_acc: 0.68
# Epoch: 067, train_loss: 0.593, test_loss:0.575, train_acc: 0.70, test_acc: 0.68
# Epoch: 068, train_loss: 0.579, test_loss:0.576, train_acc: 0.71, test_acc: 0.69
# Epoch: 069, train_loss: 0.606, test_loss:0.576, train_acc: 0.71, test_acc: 0.69
# Epoch: 070, train_loss: 0.608, test_loss:0.575, train_acc: 0.71, test_acc: 0.69
# Epoch: 071, train_loss: 0.601, test_loss:0.573, train_acc: 0.70, test_acc: 0.68
# Epoch: 072, train_loss: 0.595, test_loss:0.573, train_acc: 0.70, test_acc: 0.68
# Epoch: 073, train_loss: 0.581, test_loss:0.572, train_acc: 0.70, test_acc: 0.68
# Epoch: 074, train_loss: 0.591, test_loss:0.572, train_acc: 0.71, test_acc: 0.69
# Epoch: 075, train_loss: 0.592, test_loss:0.573, train_acc: 0.72, test_acc: 0.70
# Epoch: 076, train_loss: 0.589, test_loss:0.575, train_acc: 0.73, test_acc: 0.70
# Epoch: 077, train_loss: 0.587, test_loss:0.576, train_acc: 0.73, test_acc: 0.70
# Epoch: 078, train_loss: 0.585, test_loss:0.573, train_acc: 0.73, test_acc: 0.70
# Epoch: 079, train_loss: 0.592, test_loss:0.569, train_acc: 0.72, test_acc: 0.69
# Epoch: 080, train_loss: 0.592, test_loss:0.566, train_acc: 0.70, test_acc: 0.69
# Epoch: 081, train_loss: 0.582, test_loss:0.565, train_acc: 0.70, test_acc: 0.68
# Epoch: 082, train_loss: 0.593, test_loss:0.565, train_acc: 0.70, test_acc: 0.69
# Epoch: 083, train_loss: 0.594, test_loss:0.566, train_acc: 0.71, test_acc: 0.69
# Epoch: 084, train_loss: 0.595, test_loss:0.568, train_acc: 0.72, test_acc: 0.70
# Epoch: 085, train_loss: 0.592, test_loss:0.568, train_acc: 0.72, test_acc: 0.70
# Epoch: 086, train_loss: 0.594, test_loss:0.567, train_acc: 0.72, test_acc: 0.69
# Epoch: 087, train_loss: 0.587, test_loss:0.566, train_acc: 0.71, test_acc: 0.70
# Epoch: 088, train_loss: 0.601, test_loss:0.566, train_acc: 0.71, test_acc: 0.70
# Epoch: 089, train_loss: 0.584, test_loss:0.566, train_acc: 0.71, test_acc: 0.70
# Epoch: 090, train_loss: 0.587, test_loss:0.566, train_acc: 0.71, test_acc: 0.70
# Epoch: 091, train_loss: 0.576, test_loss:0.567, train_acc: 0.71, test_acc: 0.70
# Epoch: 092, train_loss: 0.586, test_loss:0.567, train_acc: 0.72, test_acc: 0.70
# Epoch: 093, train_loss: 0.586, test_loss:0.567, train_acc: 0.73, test_acc: 0.70
# Epoch: 094, train_loss: 0.593, test_loss:0.566, train_acc: 0.73, test_acc: 0.70
# Epoch: 095, train_loss: 0.580, test_loss:0.564, train_acc: 0.73, test_acc: 0.70
# Epoch: 096, train_loss: 0.579, test_loss:0.563, train_acc: 0.72, test_acc: 0.70
# Epoch: 097, train_loss: 0.579, test_loss:0.561, train_acc: 0.72, test_acc: 0.70
# Epoch: 098, train_loss: 0.589, test_loss:0.560, train_acc: 0.71, test_acc: 0.70
# Epoch: 099, train_loss: 0.581, test_loss:0.559, train_acc: 0.71, test_acc: 0.70
# Epoch: 100, train_loss: 0.576, test_loss:0.560, train_acc: 0.73, test_acc: 0.70
# Epoch: 101, train_loss: 0.578, test_loss:0.561, train_acc: 0.73, test_acc: 0.70
# Epoch: 102, train_loss: 0.598, test_loss:0.559, train_acc: 0.73, test_acc: 0.70
# Epoch: 103, train_loss: 0.592, test_loss:0.557, train_acc: 0.72, test_acc: 0.70
# Epoch: 104, train_loss: 0.591, test_loss:0.556, train_acc: 0.70, test_acc: 0.68
# Epoch: 105, train_loss: 0.572, test_loss:0.556, train_acc: 0.72, test_acc: 0.69
# Epoch: 106, train_loss: 0.572, test_loss:0.557, train_acc: 0.73, test_acc: 0.70
# Epoch: 107, train_loss: 0.583, test_loss:0.558, train_acc: 0.73, test_acc: 0.70
# Epoch: 108, train_loss: 0.590, test_loss:0.557, train_acc: 0.73, test_acc: 0.70
# Epoch: 109, train_loss: 0.589, test_loss:0.554, train_acc: 0.73, test_acc: 0.70
# Epoch: 110, train_loss: 0.578, test_loss:0.551, train_acc: 0.72, test_acc: 0.70
# Epoch: 111, train_loss: 0.573, test_loss:0.550, train_acc: 0.72, test_acc: 0.70
# Epoch: 112, train_loss: 0.582, test_loss:0.549, train_acc: 0.73, test_acc: 0.70
# Epoch: 113, train_loss: 0.572, test_loss:0.549, train_acc: 0.73, test_acc: 0.70
# Epoch: 114, train_loss: 0.589, test_loss:0.549, train_acc: 0.73, test_acc: 0.71
# Epoch: 115, train_loss: 0.580, test_loss:0.547, train_acc: 0.74, test_acc: 0.71
# Epoch: 116, train_loss: 0.570, test_loss:0.544, train_acc: 0.73, test_acc: 0.70
# Epoch: 117, train_loss: 0.569, test_loss:0.542, train_acc: 0.73, test_acc: 0.70
# Epoch: 118, train_loss: 0.576, test_loss:0.541, train_acc: 0.73, test_acc: 0.70
# Epoch: 119, train_loss: 0.579, test_loss:0.540, train_acc: 0.73, test_acc: 0.71
# Epoch: 120, train_loss: 0.559, test_loss:0.539, train_acc: 0.74, test_acc: 0.72
# Epoch: 121, train_loss: 0.583, test_loss:0.538, train_acc: 0.74, test_acc: 0.73
# Epoch: 122, train_loss: 0.567, test_loss:0.535, train_acc: 0.74, test_acc: 0.73
# Epoch: 123, train_loss: 0.559, test_loss:0.531, train_acc: 0.74, test_acc: 0.73
# Epoch: 124, train_loss: 0.562, test_loss:0.529, train_acc: 0.73, test_acc: 0.71
# Epoch: 125, train_loss: 0.551, test_loss:0.528, train_acc: 0.73, test_acc: 0.71
# Epoch: 126, train_loss: 0.554, test_loss:0.528, train_acc: 0.73, test_acc: 0.71
# Epoch: 127, train_loss: 0.553, test_loss:0.526, train_acc: 0.74, test_acc: 0.72
# Epoch: 128, train_loss: 0.560, test_loss:0.525, train_acc: 0.75, test_acc: 0.73
# Epoch: 129, train_loss: 0.562, test_loss:0.525, train_acc: 0.75, test_acc: 0.73
# Epoch: 130, train_loss: 0.550, test_loss:0.522, train_acc: 0.75, test_acc: 0.73
# Epoch: 131, train_loss: 0.546, test_loss:0.520, train_acc: 0.75, test_acc: 0.73
# Epoch: 132, train_loss: 0.550, test_loss:0.521, train_acc: 0.75, test_acc: 0.73
# Epoch: 133, train_loss: 0.545, test_loss:0.523, train_acc: 0.75, test_acc: 0.73
# Epoch: 134, train_loss: 0.530, test_loss:0.521, train_acc: 0.75, test_acc: 0.73
# Epoch: 135, train_loss: 0.547, test_loss:0.520, train_acc: 0.76, test_acc: 0.73
# Epoch: 136, train_loss: 0.546, test_loss:0.520, train_acc: 0.76, test_acc: 0.73
# Epoch: 137, train_loss: 0.535, test_loss:0.520, train_acc: 0.76, test_acc: 0.72
# Epoch: 138, train_loss: 0.550, test_loss:0.524, train_acc: 0.76, test_acc: 0.72
# Epoch: 139, train_loss: 0.538, test_loss:0.528, train_acc: 0.75, test_acc: 0.70
# Epoch: 140, train_loss: 0.539, test_loss:0.525, train_acc: 0.75, test_acc: 0.69
# Epoch: 141, train_loss: 0.530, test_loss:0.525, train_acc: 0.74, test_acc: 0.69
# Epoch: 142, train_loss: 0.531, test_loss:0.526, train_acc: 0.75, test_acc: 0.68
# Epoch: 143, train_loss: 0.535, test_loss:0.529, train_acc: 0.75, test_acc: 0.67
# Epoch: 144, train_loss: 0.527, test_loss:0.532, train_acc: 0.75, test_acc: 0.69
# Epoch: 145, train_loss: 0.543, test_loss:0.530, train_acc: 0.75, test_acc: 0.69
# Epoch: 146, train_loss: 0.547, test_loss:0.530, train_acc: 0.75, test_acc: 0.68
# Epoch: 147, train_loss: 0.537, test_loss:0.532, train_acc: 0.75, test_acc: 0.66
# Epoch: 148, train_loss: 0.531, test_loss:0.535, train_acc: 0.75, test_acc: 0.66
# Epoch: 149, train_loss: 0.529, test_loss:0.537, train_acc: 0.75, test_acc: 0.66
# Epoch: 150, train_loss: 0.519, test_loss:0.530, train_acc: 0.75, test_acc: 0.67
# Epoch: 151, train_loss: 0.521, test_loss:0.529, train_acc: 0.76, test_acc: 0.70
# Epoch: 152, train_loss: 0.520, test_loss:0.532, train_acc: 0.76, test_acc: 0.71
# Epoch: 153, train_loss: 0.506, test_loss:0.533, train_acc: 0.76, test_acc: 0.71
# Epoch: 154, train_loss: 0.546, test_loss:0.536, train_acc: 0.76, test_acc: 0.69
# Epoch: 155, train_loss: 0.522, test_loss:0.534, train_acc: 0.76, test_acc: 0.68
# Epoch: 156, train_loss: 0.519, test_loss:0.527, train_acc: 0.75, test_acc: 0.69
# Epoch: 157, train_loss: 0.518, test_loss:0.524, train_acc: 0.74, test_acc: 0.70
# Epoch: 158, train_loss: 0.531, test_loss:0.528, train_acc: 0.75, test_acc: 0.68
# Epoch: 159, train_loss: 0.527, test_loss:0.537, train_acc: 0.76, test_acc: 0.66
# Epoch: 160, train_loss: 0.528, test_loss:0.537, train_acc: 0.76, test_acc: 0.67
# Epoch: 161, train_loss: 0.533, test_loss:0.530, train_acc: 0.76, test_acc: 0.71
# Epoch: 162, train_loss: 0.528, test_loss:0.525, train_acc: 0.76, test_acc: 0.72
# Epoch: 163, train_loss: 0.523, test_loss:0.522, train_acc: 0.75, test_acc: 0.73
# Epoch: 164, train_loss: 0.525, test_loss:0.522, train_acc: 0.75, test_acc: 0.73
# Epoch: 165, train_loss: 0.529, test_loss:0.526, train_acc: 0.76, test_acc: 0.69
# Epoch: 166, train_loss: 0.514, test_loss:0.531, train_acc: 0.75, test_acc: 0.68
# Epoch: 167, train_loss: 0.522, test_loss:0.534, train_acc: 0.75, test_acc: 0.68
# Epoch: 168, train_loss: 0.517, test_loss:0.531, train_acc: 0.76, test_acc: 0.70
# Epoch: 169, train_loss: 0.521, test_loss:0.528, train_acc: 0.76, test_acc: 0.71
# Epoch: 170, train_loss: 0.510, test_loss:0.525, train_acc: 0.76, test_acc: 0.72
# Epoch: 171, train_loss: 0.508, test_loss:0.523, train_acc: 0.76, test_acc: 0.73
# Epoch: 172, train_loss: 0.535, test_loss:0.525, train_acc: 0.76, test_acc: 0.71
# Epoch: 173, train_loss: 0.521, test_loss:0.532, train_acc: 0.76, test_acc: 0.68
# Epoch: 174, train_loss: 0.511, test_loss:0.536, train_acc: 0.76, test_acc: 0.69
# Epoch: 175, train_loss: 0.546, test_loss:0.535, train_acc: 0.76, test_acc: 0.69
# Epoch: 176, train_loss: 0.535, test_loss:0.530, train_acc: 0.76, test_acc: 0.70
# Epoch: 177, train_loss: 0.514, test_loss:0.526, train_acc: 0.76, test_acc: 0.71
# Epoch: 178, train_loss: 0.503, test_loss:0.524, train_acc: 0.75, test_acc: 0.72
# Epoch: 179, train_loss: 0.540, test_loss:0.526, train_acc: 0.76, test_acc: 0.71
# Epoch: 180, train_loss: 0.537, test_loss:0.536, train_acc: 0.76, test_acc: 0.67
# Epoch: 181, train_loss: 0.521, test_loss:0.543, train_acc: 0.77, test_acc: 0.65
# Epoch: 182, train_loss: 0.517, test_loss:0.543, train_acc: 0.76, test_acc: 0.66
# Epoch: 183, train_loss: 0.530, test_loss:0.536, train_acc: 0.76, test_acc: 0.68
# Epoch: 184, train_loss: 0.522, test_loss:0.530, train_acc: 0.76, test_acc: 0.71
# Epoch: 185, train_loss: 0.528, test_loss:0.526, train_acc: 0.76, test_acc: 0.73
# Epoch: 186, train_loss: 0.537, test_loss:0.525, train_acc: 0.75, test_acc: 0.70
# Epoch: 187, train_loss: 0.529, test_loss:0.530, train_acc: 0.76, test_acc: 0.68
# Epoch: 188, train_loss: 0.531, test_loss:0.539, train_acc: 0.77, test_acc: 0.66
# Epoch: 189, train_loss: 0.525, test_loss:0.545, train_acc: 0.77, test_acc: 0.63
# Epoch: 190, train_loss: 0.517, test_loss:0.542, train_acc: 0.77, test_acc: 0.65
# Epoch: 191, train_loss: 0.525, test_loss:0.534, train_acc: 0.77, test_acc: 0.69
# Epoch: 192, train_loss: 0.521, test_loss:0.527, train_acc: 0.77, test_acc: 0.72
# Epoch: 193, train_loss: 0.535, test_loss:0.523, train_acc: 0.76, test_acc: 0.73
# Epoch: 194, train_loss: 0.520, test_loss:0.521, train_acc: 0.75, test_acc: 0.71
# Epoch: 195, train_loss: 0.532, test_loss:0.523, train_acc: 0.76, test_acc: 0.69
# Epoch: 196, train_loss: 0.530, test_loss:0.530, train_acc: 0.76, test_acc: 0.68
# Epoch: 197, train_loss: 0.526, test_loss:0.534, train_acc: 0.77, test_acc: 0.67
# Epoch: 198, train_loss: 0.525, test_loss:0.534, train_acc: 0.77, test_acc: 0.69
# Epoch: 199, train_loss: 0.525, test_loss:0.534, train_acc: 0.77, test_acc: 0.73
