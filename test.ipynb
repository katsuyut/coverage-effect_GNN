# %%
import numpy as np
import os.path as osp
from random import shuffle, randint
import networkx as nx
import matplotlib.pyplot as plt
import random
from sklearn.preprocessing import StandardScaler
import argparse
import pickle
from statistics import stdev

# %%
case = 'noname'
# nepoch = 10
mo = 'simple'
nconv = 1
datatype = 'data'
ytype = 'slab' # 3:slab, 4:space, 5:all
# lr = 0.001
save = 'no'

# %%
with open('data.pickle', 'rb') as lb:
    rdata = pickle.load(lb)
    edge_indexes,features,surf_filters,ys_slab,ys_space,ys_all = rdata
    
plt.hist(ys_slab)
plt.show()
plt.hist(ys_space)
plt.show()
plt.hist(ys_all)
plt.show()
stdev(ys_slab),stdev(ys_space),stdev(ys_all)
# Out:
# (0.12814125400299645, 0.28145908528882224, 0.33176619936289753)

# %%
with open('data_100.pickle', 'rb') as lb:
    rdata = pickle.load(lb)
    edge_indexes,features,surf_filters,ys_slab,ys_space,ys_all = rdata
    
plt.hist(ys_slab)
plt.show()
plt.hist(ys_space)
plt.show()
plt.hist(ys_all)
plt.show()
stdev(ys_slab),stdev(ys_space),stdev(ys_all)
# Out:
# (0.10551166255821157, 0.24105660214352437, 0.28369907762404617)

# %%
with open('data_111.pickle', 'rb') as lb:
    rdata = pickle.load(lb)
    edge_indexes,features,surf_filters,ys_slab,ys_space,ys_all = rdata
    
plt.hist(ys_slab)
plt.show()
plt.hist(ys_space)
plt.show()
plt.hist(ys_all)
plt.show()
stdev(ys_slab),stdev(ys_space),stdev(ys_all)
# Out:
# (0.1495216093414759, 0.31818924580809943, 0.37646554146705574)
